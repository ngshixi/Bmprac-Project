# %% [markdown]
# <a href="https://colab.research.google.com/github/ngshixi/Bmprac-Project/blob/main/BMPrac_Report_Group6_Shi_Xi%2C_Arnav%2C_Ikhlas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# By: Shi Xi (S10265843H), Arnav (S10240968A) , Ikhlas (S10267750A) - Group 6 BMS2M02

# %% [markdown]
# **Declaration of contribution**
#
# We confirm that all members of the group contributed equally to the design, implementation, analysis, and writing of this research project.

# %% [markdown]
# Github Link
#
#
# ---

# %% [markdown]
# # Biomanufacturing Report 1

# %% [markdown]
# **Summary:**

# %% [markdown]
# This project will analyze NHANES 2007–2012 data to examine sex differences in thyroid hormone levels among Hispanic adults in the United States. By comparing mean and variability of TSH, Free T4, and Total T3 between males and females, we aim to generate updated reference estimates and highlight potential disparities. Findings may inform clinical interpretation and support early detection of thyroid dysfunction.

# %% [markdown]
# **Background:**

# %% [markdown]
# The thyroid gland, located in the anterior region of the neck, is responsible for producing and regulating key hormones involved in metabolism and energy balance. These include thyroxine (T4) and triiodothyronine (T3), which are secreted in response to stimulation by thyroid-stimulating hormone (TSH), a hormone produced by the pituitary gland. The balance of these hormones is critical for numerous physiological functions, including:
#
# 1.   Regulation of basal metabolic rate
# 2.   Cardiovascular and gastrointestinal activity
# 3.   Muscular development and bone turnover
# 4.   Brain development and neurocognitive functioning
#
# ![719086-571.jpg](data:image/jpeg;base64,...)
#
# TSH is the most commonly used biomarker to assess thyroid health due to its sensitivity to even slight changes in circulating T3 and T4 levels. Free T4 (FT4) represents the unbound, biologically active form of thyroxine, while total T3 provides an estimate of overall triiodothyronine activity. Clinically, these markers are used to diagnose and monitor thyroid disorders such as:
#
# 1. Hypothyroidism, associated with low FT4 and elevated TSH levels
# 2. Hyperthyroidism, associated with high FT4/T3 and suppressed TSH levels
#
# Even in the absence of overt disease, subclinical abnormalities in thyroid hormone levels can contribute to metabolic disturbances, fatigue, and increased cardiovascular risk. Therefore, understanding patterns in hormone distribution, particularly within specific populations, is important for early identification of thyroid dysfunction and for refining public health interventions.
#
# Prior studies have shown that thyroid hormone concentrations can differ by demographic factors such as age, sex, and race/ethnicity. For example, women are known to have a higher prevalence of autoimmune thyroid disease, while men may present differently and be diagnosed less frequently (Hollowell et al., 2002). Hispanic adults are an understudied group in thyroid epidemiology, and there is limited data describing sex-specific distributions of TSH, Free T4, and Total T3 within this population.
#
# Furthermore, much of the existing evidence is based on older surveys or studies conducted outside the United States. Since the early 2000s, shifts in iodine intake, obesity prevalence, and smoking behaviors may have altered thyroid hormone distributions in the US Hispanic population. NHANES data from 2007–2012 uniquely include standardized laboratory measures of all three classical thyroid markers in a nationally representative sample.

# %% [markdown]
# **RESEARCH QUESTION:**

# %% [markdown]
# ---
#
#
# **Among Hispanic adults aged 18 years and older in the United States, between 2007 and 2012, how do serum concentrations of thyroid-stimulating hormone (TSH), free thyroxine (FT4), and total triiodothyronine (Total T3) differ between males and females in terms of both mean and standard deviation?**
#
#
#
# ---

# %% [markdown]
# This question focuses on a specific ethnic group, Hispanic adults in the U.S. over a defined time period (2007-2012), using gender as the main comparative variable and three key thyroid biomarkers as the outcomes. The aim is a descriptive statistical comparison that highlights not only the central tendency (mean) but also the variability (standard deviation) of hormone levels between males and females.

# %% [markdown]
# **Rationale:**

# %% [markdown]
# ---
#
#
# This study aims to fill an important knowledge gap by characterizing the distributions of TSH, Free T4, and Total T3 among Hispanic adults in the United States, with a specific focus on sex differences. Understanding how mean hormone levels and their variability differ between Hispanic males and females can inform clinical interpretation of laboratory results and guide population health strategies for early detection of thyroid dysfunction.
#
# Our analysis will leverage publicly available NHANES data to provide updated, representative estimates that can serve as reference points for clinicians and researchers. By focusing on a demographic group often underrepresented in thyroid studies, this project contributes to more equitable and evidence-based endocrine care.

# %% [markdown]
# **Justification for Originality:**

# %% [markdown]
# ---
#
#
# Previous large-scale studies have examined thyroid hormone distributions across U.S. populations. A landmark study by Hollowell et al. (2002), using NHANES III (1988-1994) data, provided valuable reference ranges for TSH and total T4 and reported differences by age, sex, and race. However, this dataset is now outdated, and critically, it did not include FT4 or Total T3, hormones now considered essential for a comprehensive thyroid profile. Moreover, it did not account for emerging lifestyle and behavioral factors such as smoking, BMI, or alcohol use, which are now recognized as key modifiers of thyroid function.
#
# In contrast, Alevizaki et al. (2005) conducted a European cohort study that found FT4 to be a stronger predictor of lipid abnormalities than TSH. While informative, the study used a limited sample and did not include NHANES data or account for racial and ethnic diversity, which restricts its generalizability to U.S. subpopulations.
#
# To our knowledge, no study to date has simultaneously examined TSH, FT4, and Total T3 in relation to demographic (e.g., gender, age, ethnicity), lifestyle (e.g., smoking, alcohol use, physical activity), and physiological (e.g., BMI, income) variables using the more recent and standardized NHANES cycles from 2007-2012. These cycles uniquely offer consistent laboratory methodology across all three thyroid hormones, enabling reliable comparisons.
#
# Our study specifically fills this gap by focusing on Hispanic adults, a group that has been underrepresented in thyroid health literature. By investigating gender-based differences in both the mean and variability of hormone levels, we aim to provide updated, demographically relevant reference values and potentially uncover previously unreported disparities. This can ultimately support more precise and equitable public health strategies for thyroid screening.

# %% [markdown]
# **Contribution to Existing Literature:**

# %% [markdown]
# ---
#
#
# This project contributes to existing literature by offering a distribution-based perspective on thyroid hormone levels, rather than focusing solely on mean values or clinical thresholds. Most prior studies have presented pooled averages or prevalence data, which can mask important intra-group differences.
#
# By examining standard deviations, this study provides insight into the consistency and variability of thyroid hormone regulation within each gender group. Such variability could be influenced by factors like hormonal cycles, metabolic rate differences, stress levels, or socioeconomic disparities all of which warrant further exploration. This descriptive and stratified analysis can inform more personalized screening criteria and improve population health monitoring among Hispanic adults in the U.S.

# %% [markdown]
# **Objectives of the Study (SMART):**

# %% [markdown]
# The following SMART objectives have been established to guide the analysis:
#
# - Specific: To evaluate gender-based differences in serum levels of TSH, FT4, and Total T3 among Hispanic adults aged 18 years and older in the U.S., using NHANES 2007-2012 data.
#
# - Measurable: To calculate and compare the means and standard deviations of these biomarkers by gender.
# Achievable: Data will be extracted from the NHANES publicly available datasets, which are nationally representative and contain standardized laboratory values.
#
# - Achievable: Data will be extracted from the NHANES publicly available datasets, which are nationally representative and contain standardized laboratory values.
#
# - Relevant: Findings will inform whether gender-based biological or lifestyle factors influence thyroid hormone variability in an underrepresented population.
#
# - Time-bound: All data cleaning, statistical analysis, interpretation, and reporting will be completed within the course’s designated timeline.
#
# - Creating clear visual representations of hormone distributions by gender using boxplots and histograms.
#
# - Identifying and commenting on any trends or patterns in hormone variability that may warrant further research.

# %% [markdown]
# # Inclusion Criteria
#
# | Criteria        | Variable Name | Source Dataset  | Codes                                                                 | Description                               |
# | :-------------- | :------------ | :-------------- | :-------------------------------------------------------------------- | :---------------------------------------- |
# | Race/Ethnicity  | RIDRETH1      | DEMO_F-DEMO_J (2007-2012) | 1-Mexican American, 2-Other Hispanic, 3-Non-hispanic White, 4-Hispanic black, 5-Other Race- Including Multi-Racial | To distinguish between hispanic and non-hispanics. |
# | Age             | RIDAGEYR      | DEMO_F-DEMO_J (2007-2018) | 0-79, 80>                                                             | Age to be greater than 18 years           |

# %% [markdown]
# Sample size

# %%
# Compute and print sample size
sample_size = df_clean.shape[0]
print(f"Final sample size: {sample_size} Hispanic adults with complete thyroid data (2007–2012)")
# Out:
# Final sample size: 2408 Hispanic adults with complete thyroid data (2007–2012)

# %% [markdown]
# # Measured Biomarkers
# Selected Biomarkers:
#
# | Variable name   | Codes                     | Source Dataset           | Description                                     | Clinical Significance                                                                                                                                                               |
# | :-------------- | :------------------------ | :----------------------- | :---------------------------------------------- | :---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | LBXT4F          | Continuous - ng/dL        | THYROD_E THYROD_F THYROD_G (2007-2011) | Thyroxine, free (ng/dL)                         | Biomarker. Thyroxine (T4) along with Triiodothyronine (T3) both make up the “Thyroid hormone”, fluctuations in this concentration will show abnormal thyroid secretions. The healthy range for Free T4 is 0.8 to 1.8 or 1.9 ng/dL |
# | LBXTT3          | Continuous - ng/dL        | THYROD_E THYROD_F THYROD_G (2007-2011) | Triiodothyronine (T3), total (ng/dL)              | Biomarker. Triiodothyronine (T3) along with Thyroxine (T4) makes up the “Thyroid hormone”, fluctuations in this concentration will show abnormal thyroid secretions. 79-165 ng/dL                               |
# | LBXTSH1         | Continuous - uIU/mL       | THYROD_E THYROD_F THYROD_G (2007-2011) | Thyroid stimulating hormone (uIU/mL)            | Biomarker. TSH stimulates the thyroid to release thyroid hormone, TSH concentrations outside of the optimal range will result in over or under stimulation of the thyroid. 0.27 - 4.2 uIU/mL                            |

# %% [markdown]
# # Categorical & Continuous Variables
#
# Categorical variables:
#
# | Variable name   | Codes                     | Source Dataset           | Description                                     | Clinical Significance                               |
# | :-------------- | :------------------------ | :----------------------- | :---------------------------------------------- | :-------------------------------------------------- |
# | RIAGENDR        | 1 – Male, 2 – Female      | DEMO_F – DEMO_J (2007–2018) | Gender                                          | Evaluates if risk factors impact individuals differently based on gender |
# | URXUIO          | Continuous - ug/L         | UIO_E, UIO_G (2007-2012)  | Iodine, Urine ug/L                              | Evaluates if iodine concentration affects the thyroid hormone (Binned Q1-Q4) |
# | ALQ101          | 1- Yes, 2- No, 7- Refused, 9- Don’t know | ALQ_E-ALQ_G (2007-2012) | Had at least 12 alcohol drinks/1 yr?            | Evaluates of alcohol affects the thyroid function |
# | RIDAGEYR        | 0-79, 80>                 | DEMO_F-DEMO_J (2007-2018) | Age                                             | Evaluates if age impacts thyroid functionality (Binned 18-29,...) |
# | BMXBMI          | Continuous - kg/m**2      | BMX_E - BMX_G (2007-2012) | Body Mass Index (kg/m**2)                       | Evaluates of BMI affects thyroid function (Binned, Underweight, overweight..) |
# | SMQ040          | 1- Every day, 2- Some days, 3- Not at all, 7- Refused, 9- Don’t know | SMQ_E - SMQ_G (2007-2012) | How frequently do you smoke cigarettes?       | Evaluates if smoking frequency affects thyroid function |
# | SLD010H         | 1 to 11-Range of values, 12- 12 hours or more, 77- refused, 99- don’t know | SLQ_E-SLQ_G (2007-2012) | The next set of questions is about your sleeping habits. How much sleep {do you/does SP} usually get at night on weekdays or workdays? | Evaluates if sleep duration in hours affects thyroid function |

# %% [markdown]
# Continuous Variable
#
# | Variable name   | Codes                     | Source Dataset           | Description                                     | Clinical Significance                               |
# | :-------------- | :------------------------ | :----------------------- | :---------------------------------------------- | :-------------------------------------------------- |
# | RIDAGEYR        | 0-79, 80>                 | DEMO_F-DEMO_J (2007-2018) | Age                                             | Evaluates if age impacts thyroid functionality (Binned 18-29,...) |
# | BMXBMI          | Continuous - kg/m**2      | BMX_E - BMX_G (2007-2012) | Body Mass Index (kg/m**2)                       | Evaluates of BMI affects thyroid function (Binned, Underweight, overweight..) |
# | URXUIO          | Continuous - ug/L         | UIO_E, UIO_G (2007-2012)  | Iodine, Urine ug/L                              | Evaluates if iodine concentration affects the thyroid hormone (Binned Q1-Q4) |

# %% [markdown]
# # Histogram + calculations

# %% [markdown]
# ***Extracting, merging and filtering data***
#
#
# ---
#
#
# What this code does is that it first configures our dataset with the necessary prefixes and demographics.
#
# The next part of the code loads the data from Nhanes using the configured dataset and only loads the specified data. (There is another way where you directly download the xpt files and load it from there, but this a much faster method. But this loading code must always be run before any of the code below or else nothing is produced)
#
# The next part of the code cleaning and filtering, the data that we retrieve from Nhanes is raw, it contains the results for people didn't produce a result.
#
# For example from one of our modules, we need to change the code for 7 (I don't know) and 9 (Refused) to NaN. Next using dropna function to drop these variables in order to form a clean dataframe.
#
# In the end producing df_clean,
# which will be used in the rest of our codes

# %%
import pandas as pd
import numpy as np

# --------------------------------
# Dataset Configuration
# --------------------------------
years = ["2007", "2009", "2011"]
cycles = ["E", "F", "G"]

modules = {
    "demographics": {
        "prefix": "DEMO",
        "vars": ["SEQN", "RIAGENDR", "RIDAGEYR", "RIDRETH1"]
    },
    "bmi": {
        "prefix": "BMX",
        "vars": ["SEQN", "BMXBMI"]
    },
    "smoking": {
        "prefix": "SMQ",
        "vars": ["SEQN", "SMQ040"]
    },
    "alcohol": {
        "prefix": "ALQ",
        "vars": ["SEQN", "ALQ101"]
    },
    "iodine": {
        "prefix": "UIO",
        "vars": ["SEQN", "URXUIO"]
    },
    "thyroid": {
        "prefix": "THYROD",
        "vars": ["SEQN", "LBXT4F", "LBXTT3", "LBXTSH1"]
    },
    "sleep": {
        "prefix": "SLQ",
        "vars": ["SEQN", "SLD010H"]
    }
}

# --------------------------------
# Load and Merge NHANES Data
# --------------------------------
def load_nhanes(years, cycles):
    dfs = {}
    for label, config in modules.items():
        prefix = config["prefix"]
        vars_needed = config["vars"]
        df_list = []
        for y, c in zip(years, cycles):
            url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{y}/DataFiles/{prefix}_{c}.XPT"
            temp = pd.read_sas(url)[vars_needed]
            df_list.append(temp)
        df = pd.concat(df_list, ignore_index=True)
        dfs[label] = df

    df = dfs["demographics"]
    for label, sub_df in dfs.items():
        if label != "demographics":
            df = df.merge(sub_df, on="SEQN", how="inner")
    return df

# --------------------------------
# Clean and Filter for Hispanic Adults
# --------------------------------
def prepare_dataset(df):
    df = df.copy()

    # Recode Gender and Race
    df["Gender"] = df["RIAGENDR"].map({1: "Male", 2: "Female"})
    df["Race"] = df["RIDRETH1"].map({
        1: "Mexican American",
        2: "Other Hispanic",
        3: "Non-Hispanic White",
        4: "Non-Hispanic Black",
        5: "Other/Multi-Racial"
    })

    # Replace known missing codes with NaN
    df.replace({7777: np.nan, 9999: np.nan, 8888: np.nan, 99999: np.nan}, inplace=True)
    df["SLD010H"] = df["SLD010H"].replace({77: np.nan, 99: np.nan})
    df["SMQ040"] = df["SMQ040"].replace({7: np.nan, 9: np.nan})
    df["ALQ101"] = df["ALQ101"].replace({7: np.nan, 9: np.nan})

    # Drop rows missing hormone or demographic values
    df = df.dropna(subset=["LBXT4F", "LBXTT3", "LBXTSH1", "RIDAGEYR"])

    # Filter: Hispanic adults (≥18 years old)
    df = df[(df["RIDAGEYR"] >= 18) & (df["RIDRETH1"].isin([1, 2]))]

    # Select final columns
    return df[[
        "SEQN", "RIDAGEYR", "Gender", "Race", "BMXBMI", "SMQ040", "ALQ101",
        "URXUIO", "SLD010H", "LBXT4F", "LBXTT3", "LBXTSH1"
    ]]

# --------------------------------
# Run Pipeline
# --------------------------------
df_raw = load_nhanes(years, cycles)
df_clean = prepare_dataset(df_raw)

# df_clean is now ready for analysis

# %% [markdown]
# Next I'll explain how the code below works,
#
# The next codes do not require us to load data or merge anymore.
#
# This is as the first code produces df_clean and once df_clean is defined,
# the code below will utilise the dataframe in order to produce our desired results.
#
# e.g. (analyze_alcohol_vs_thyroid(df_clean))
#
# Of course we also need the code that actually helps us visualise and compute our results
#
# For example, our code runs tests for Shapiro-Wilk test, Mann-Whitney U or Kruskal-Wallis and calculates mean, median just to list a few.

# %% [markdown]
# # **Alcohol consumption**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis, shapiro, mannwhitneyu, kruskal
import numpy as np

# --------------------------------
# Run Descriptive Stats and Non-Parametric Tests
# --------------------------------
def run_stats(df, hormone, group_col):
    print(f"\n📊 {hormone} Analysis by {group_col}:")

    # Frequency table
    freq_table = df[group_col].value_counts(dropna=False)
    print("\nFrequency Table:")
    print(freq_table)

    # Grouped data
    grouped = df.groupby(group_col)[hormone]

    # Descriptive Stats
    print("\nDescriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):")
    stats_table = grouped.agg([
        'count', 'mean', 'median', 'std',
        lambda x: x.quantile(0.25),
        lambda x: x.quantile(0.75)
    ])
    stats_table.columns = ["N", "Mean", "Median", "Std", "Q1", "Q3"]
    stats_table["IQR"] = stats_table["Q3"] - stats_table["Q1"]
    print(stats_table)

    # Shapiro-Wilk, Skewness, Kurtosis
    print("\nNormality Tests and Distribution Metrics:")
    for group, data in grouped:
        values = data.dropna()
        if len(values) < 3:
            print(f"{group}: Not enough data (N={len(values)})")
            continue
        s, p = shapiro(values) if len(values) <= 5000 else (np.nan, np.nan)
        print(f"\nGroup: {group}")
        print(f"  N = {len(values)}")
        print(f"  Skewness: {skew(values):.4f}")
        print(f"  Kurtosis: {kurtosis(values):.4f}")
        if not np.isnan(s):
            print(f"  Shapiro-Wilk: W={s:.4f}, p = {p:.4f} →", "Not normal" if p < 0.05 else "Normal")
        else:
            print("  Shapiro-Wilk skipped (N > 5000)")

    # Non-parametric comparison
    clean_groups = [g.dropna() for _, g in grouped if len(g.dropna()) >= 3]
    if len(clean_groups) >= 2:
        if len(clean_groups) == 2:
            u_stat, pval = mannwhitneyu(*clean_groups, alternative="two-sided")
            print(f"\nMann–Whitney U Test: U = {u_stat:.4f}, p = {pval:.4f}")
            print("→ Significant difference (non-parametric)" if pval < 0.05 else "→ No significant difference")
        else:
            kw_stat, kw_pval = kruskal(*clean_groups)
            print(f"\nKruskal–Wallis Test: H = {kw_stat:.4f}, p = {kw_pval:.4f}")
            print("→ Significant difference (non-parametric)" if kw_pval < 0.05 else "→ No significant difference")
    else:
        print("\n→ Not enough valid groups for statistical testing")

# --------------------------------
# Plot Histograms, Bar Charts, and Run Stats
# --------------------------------
def analyze_alcohol_vs_thyroid(df):
    df = df.copy()
    df["Alcohol_Consumption"] = df["ALQ101"].map({1: "Yes", 2: "No"})
    df = df.dropna(subset=["Alcohol_Consumption"])

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        # Plotting side-by-side histograms for each hormone by alcohol consumption
        plt.figure(figsize=(12, 6))

        # Histogram
        plt.subplot(1, 2, 1)
        sns.histplot(data=df, x=hvar, hue="Alcohol_Consumption", kde=True, bins=30, multiple="stack", palette="Set2")
        plt.title(f"{hname} by Alcohol Consumption")
        plt.xlabel(hname)
        plt.ylabel("Frequency")
        plt.tight_layout()

        # Bar plot for Mean ± Std
        plt.subplot(1, 2, 2)
        stats_df = df.groupby("Alcohol_Consumption")[hvar].agg(['mean', 'std']).reset_index()
        plt.bar(stats_df["Alcohol_Consumption"], stats_df["mean"], yerr=stats_df["std"],
                capsize=6, color=["#66c2a5", "#fc8d62"])
        plt.ylabel(f"Mean {hname}")
        plt.title(f"{hname}: Mean ± SD by Alcohol Consumption")
        plt.grid(axis='y', linestyle='--', alpha=0.6)
        plt.tight_layout()
        plt.show()

        # Run stats
        run_stats(df, hvar, "Alcohol_Consumption")

# --------------------------------
# Run the Analysis
# --------------------------------
analyze_alcohol_vs_thyroid(df_clean)
# Out:
# 📊 LBXT4F Analysis by Alcohol_Consumption:
#
# Frequency Table:
# Alcohol_Consumption
# Yes    1539
# No      676
# Name: count, dtype: int64
#
# Descriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):
#                         N      Mean  Median       Std   Q1   Q3  IQR
# Alcohol_Consumption
# No                    676  0.795399     0.8  0.153179  0.7  0.9  0.2
# Yes                  1539  0.801527     0.8  0.187890  0.7  0.9  0.2
#
# Normality Tests and Distribution Metrics:
#
# Group: No
#   N = 676
#   Skewness: 1.0291
#   Kurtosis: 4.4170
#   Shapiro-Wilk: W=0.9265, p = 0.0000 → Not normal
#
# Group: Yes
#   N = 1539
#   Skewness: 7.8355
#   Kurtosis: 142.0723
#   Shapiro-Wilk: W=0.6469, p = 0.0000 → Not normal
#
# Mann–Whitney U Test: U = 516696.5000, p = 0.7987
# → No significant difference
# 📊 LBXTT3 Analysis by Alcohol_Consumption:
#
# Frequency Table:
# Alcohol_Consumption
# Yes    1539
# No      676
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# **Analysis of results (Alcohol)**
#
#
#
#
#
#
#
# ---
#
#
#
# **Free T4**
# What it does: Free T4 is a thyroid hormone that helps regulate metabolism and energy use.
#
# Findings:
# - Mean values: Very similar (No = 0.795, Yes = 0.802)
# - Mann-Whitney U Test p = 0.7987 → No significant difference
# - Both groups have non-normal distributions, especially in the alcohol group (very high skewness and kurtosis).
#
# Interpretation:
# Alcohol consumption does not significantly affect Free T4 levels. The hormone levels are stable across both groups.
#
# **Total T3**
# What it does: Total T3 plays a key role in body temperature, metabolism, and heart rate.
#
# Findings:
# - Mean values: Slightly higher in alcohol group (No = 116.2, Yes = 118.3)
# - Mann-Whitney U Test p = 0.0822 → No statistically significant difference, but closer to significance
# - Alcohol group again shows more skewed and peaked data.
#
# Interpretation:
# While there’s a slight increase in Total T3 among alcohol consumers, the difference is not statistically significant. It may suggest a trend worth further investigation, but nothing conclusive.
#
# **TSH**
# What it does: TSH stimulates the thyroid gland to produce T3 and T4; high TSH may suggest underactive thyroid, low TSH may suggest overactive thyroid.
#
# Findings:
# - Mean TSH is lower in alcohol group (No = 2.16, Yes = 1.98)
# - Mann-Whitney U Test p = 0.1199 → No significant difference
# - Extremely high skewness and kurtosis in both groups (likely due to outliers or rare cases).
#
# Interpretation:
# TSH levels show a non-significant decrease among alcohol users, but due to extreme data spread, the result isn’t reliable enough to draw conclusions.
#
# Overall Conclusion:
# - No significant differences were found in Free T4, Total T3, or TSH levels between alcohol consumers and non-consumers.
#
# - While Total T3 and TSH showed small trends, they were not statistically meaningful.
#
# - Data distributions are highly non-normal, especially in alcohol consumers, indicating the presence of extreme outliers or unusual cases.

# %% [markdown]
# Gender

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis, shapiro, mannwhitneyu, kruskal
import numpy as np

# --------------------------------
# Run Descriptive Stats and Non-Parametric Tests
# --------------------------------
def run_stats(df, hormone, group_col):
    print(f"\n📊 {hormone} Analysis by {group_col}:")

    # Frequency table
    freq_table = df[group_col].value_counts(dropna=False)
    print("\nFrequency Table:")
    print(freq_table)

    # Grouped data
    grouped = df.groupby(group_col)[hormone]

    # Descriptive Stats
    print("\nDescriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):")
    stats_table = grouped.agg([
        'count', 'mean', 'median', 'std',
        lambda x: x.quantile(0.25),
        lambda x: x.quantile(0.75)
    ])
    stats_table.columns = ["N", "Mean", "Median", "Std", "Q1", "Q3"]
    stats_table["IQR"] = stats_table["Q3"] - stats_table["Q1"]
    print(stats_table)

    # Normality Checks
    print("\nNormality Tests and Distribution Metrics:")
    for group, data in grouped:
        values = data.dropna()
        if len(values) < 3:
            print(f"{group}: Not enough data (N={len(values)})")
            continue
        s, p = shapiro(values) if len(values) <= 5000 else (np.nan, np.nan)
        print(f"\nGroup: {group}")
        print(f"  N = {len(values)}")
        print(f"  Skewness: {skew(values):.4f}")
        print(f"  Kurtosis: {kurtosis(values):.4f}")
        if not np.isnan(s):
            print(f"  Shapiro-Wilk: W={s:.4f}, p = {p:.4f} →", "Not normal" if p < 0.05 else "Normal")
        else:
            print("  Shapiro-Wilk skipped (N > 5000)")

    # Non-parametric statistical testing
    clean_groups = [g.dropna() for _, g in grouped if len(g.dropna()) >= 3]
    if len(clean_groups) >= 2:
        if len(clean_groups) == 2:
            u_stat, u_pval = mannwhitneyu(clean_groups[0], clean_groups[1], alternative="two-sided")
            print(f"\nMann–Whitney U Test: U = {u_stat:.4f}, p = {u_pval:.4f}")
            print("→ Significant difference (non-parametric)" if u_pval < 0.05 else "→ No significant difference")
        else:
            kw_stat, kw_pval = kruskal(*clean_groups)
            print(f"\nKruskal–Wallis Test: H = {kw_stat:.4f}, p = {kw_pval:.4f}")
            print("→ Significant difference (non-parametric)" if kw_pval < 0.05 else "→ No significant difference")
    else:
        print("\n→ Not enough valid groups for statistical testing")

# --------------------------------
# Plot Histograms and Run Stats for Gender (or other groups like Iodine)
# --------------------------------
def analyze_gender_vs_thyroid(df):
    df = df.copy()
    df = df.dropna(subset=["Gender"])

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        fig, ax = plt.subplots(1, 2, figsize=(18, 6))

        # Histogram
        sns.histplot(data=df, x=hvar, hue="Gender", kde=True, bins=30, multiple="stack", palette="Set2", ax=ax[0])
        ax[0].set_title(f"{hname} by Gender (Histogram)")
        ax[0].set_xlabel(hname)
        ax[0].set_ylabel("Frequency")

        # Bar plot (Mean ± SD)
        sns.barplot(
            data=df,
            x="Gender",
            y=hvar,
            estimator=np.mean,
            ci="sd",
            palette="Set2",
            errorbar="sd",
            capsize=0.2,
            ax=ax[1]
        )
        ax[1].set_title(f"{hname} by Gender (Mean ± SD)")
        ax[1].set_ylabel(hname)
        ax[1].set_xlabel("Gender")

        plt.tight_layout()
        plt.show()

        # Run stats
        run_stats(df, hvar, "Gender")

# --------------------------------
# Run Analysis
# --------------------------------
analyze_gender_vs_thyroid(df_clean)
# Out:
# /tmp/ipython-input-6-880940223.py:85: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-6-880940223.py:85: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# 📊 LBXT4F Analysis by Gender:
#
# Frequency Table:
# Gender
# Female    1279
# Male      1129
# Name: count, dtype: int64
#
# Descriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):
#            N      Mean  Median       Std   Q1   Q3  IQR
# Gender
# Female  1279  0.798921     0.8  0.200719  0.7  0.9  0.2
# Male    1129  0.800655     0.8  0.148333  0.7  0.9  0.2
#
# Normality Tests and Distribution Metrics:
#
# Group: Female
#   N = 1279
#   Skewness: 7.6851
#   Kurtosis: 130.9175
#   Shapiro-Wilk: W=0.6421, p = 0.0000 → Not normal
#
# Group: Male
#   N = 1129
#   Skewness: 2.0698
# ...

# %% [markdown]
# # **Analysis of results (Gender)**
#
# ## Gender-wise Analysis of Thyroid Markers
#
# ### Overall Summary
# - ✅ **Total T3** (p = 0.0000) and **Free T4** (p = 0.0395) shows a **statistically significant difference** between genders.
# - ❌ **TSH** (p = 0.2284) shows **no significant difference**.
# - **All groups fail normality tests** → Interpret results cautiously.
#
# ---
#
# ### 1. **Free T4 (LBXT4F)**
# **Function:** Helps regulate energy and metabolism.
# **Mann-Whitney U test p = 0.395** →  ✅**significant difference**
#
# #### Descriptive Summary:
#
# | Statistic | Female       | Male         | Comment                                    |
# |-----------|--------------|--------------|--------------------------------------------|
# | N         | 1279         | 1129         | Sample sizes are relatively balanced       |
# | Mean      | 0.799 ng/dL  | 0.801 ng/dL  | Practically identical average levels       |
# | Median    | 0.8          | 0.8          | Central tendency is the same               |
# | Std       | 0.201        | 0.148        | Slightly more variability in females       |
# | IQR       | 0.2          | 0.2          | Middle 50% range is identical              |
#
# #### Normality:
# - Female: Skew = 7.69, Kurtosis = 130.9
# - Male: Skew = 2.07, Kurtosis = 18.0
# - Shapiro-Wilk p < 0.05 → ❌ Not normal
#
# **Interpretation:**
# Free T4 levels after being analysed using Mann-Whitney U Test, have been found to **statistically significant**. Where Females have higher variation or SD compared to men.
#
# ---
#
# ### 2. **Total T3 (LBXTT3)**
# **Function:** Biologically active thyroid hormone.
# **Mann-Whitney U Test p = 0.0000** → ✅ **Significant difference**
#
# #### Trend:
# - Mean T3: Female = 116.7, Male = 119.1
# - Median and IQR similar, but males show higher mean
#
# **Interpretation:**
# Males show a significantly higher Total T3 level.
# This may reflect hormonal or metabolic differences between genders.
#
# ---
#
# ### 3. **TSH (LBXTSH1)**
# **Function:** Stimulates production of T3 and T4.
# **Mann-Whitney U Test p = 0.2284** → ❌ **Not statistically significant**
#
# #### Trend:
# - Mean TSH: Female = 2.14, Male = 1.92
#
# **Interpretation:**
# Although not statistically significant, females tend to have slightly higher TSH levels.
# Suggests potential hormonal feedback differences. Due to non-normality, consider non-parametric tests for robustness.
#
# ---
#
# ### Conclusion:
# - **T3 is significantly higher** in males.
# - **TSH is higher** in females, but not statistically significant.
# - **Free T4 is nearly identical** across genders.

# %% [markdown]
# # **Iodine in Urine**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis, shapiro, mannwhitneyu, kruskal
import numpy as np
import pandas as pd  # Ensure pandas is imported

# --------------------------------
# Statistical Summary + Normality + Mann–Whitney/Kruskal + Bar Plot
# --------------------------------
def run_stats(df, hormone, group_col):
    print(f"\n📊 {hormone} Analysis by {group_col}:")

    # Frequency table
    print("\nFrequency Table:")
    print(df[group_col].value_counts(dropna=False).sort_index())

    # Grouped descriptive stats
    grouped = df.groupby(group_col)[hormone]
    print("\nDescriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):")
    stats_table = grouped.agg([
        'count', 'mean', 'median', 'std',
        lambda x: x.quantile(0.25),
        lambda x: x.quantile(0.75)
    ])
    stats_table.columns = ["N", "Mean", "Median", "Std", "Q1", "Q3"]
    stats_table["IQR"] = stats_table["Q3"] - stats_table["Q1"]
    print(stats_table)

    # Normality stats
    print("\nNormality Tests and Distribution Metrics:")
    for group, values in grouped:
        values = values.dropna()
        if len(values) < 3:
            print(f"{group}: Not enough data (N={len(values)})")
            continue
        s, p = shapiro(values) if len(values) <= 5000 else (np.nan, np.nan)
        print(f"\nGroup: {group}")
        print(f"  N = {len(values)}")
        print(f"  Skewness: {skew(values):.4f}")
        print(f"  Kurtosis: {kurtosis(values):.4f}")
        if not np.isnan(s):
            print(f"  Shapiro-Wilk: W={s:.4f}, p = {p:.4f} →", "Not normal" if p < 0.05 else "Normal")
        else:
            print("  Shapiro-Wilk skipped (N > 5000)")

    # Decide on non-parametric test
    clean_groups = [g.dropna() for _, g in grouped if len(g.dropna()) >= 3]
    if len(clean_groups) >= 2:
        if len(clean_groups) == 2:
            u_stat, pval = mannwhitneyu(clean_groups[0], clean_groups[1], alternative="two-sided")
            print(f"\nMann–Whitney U Test: U = {u_stat:.4f}, p = {pval:.4f}")
            print("→ Significant difference (non-parametric)" if pval < 0.05 else "→ No significant difference")
        else:
            h_stat, kruskal_p = kruskal(*clean_groups)
            print(f"\nKruskal–Wallis Test: H = {h_stat:.4f}, p = {kruskal_p:.4f}")
            print("→ Significant difference (non-parametric)" if kruskal_p < 0.05 else "→ No significant difference (non-parametric)")
    else:
        print("\n→ Not enough valid groups for statistical testing")

# --------------------------------
# Plot & Analyze by Iodine Quartile
# --------------------------------
def analyze_iodine_vs_thyroid(df):
    df = df.copy()
    df = df.dropna(subset=["URXUIO"])

    # Create Iodine Quartile Group
    df["Iodine_Group"] = pd.qcut(df["URXUIO"], 4, labels=["Q1 (Low)", "Q2", "Q3", "Q4 (High)"])

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        # Histogram
        sns.histplot(
            data=df,
            x=hvar,
            hue="Iodine_Group",
            bins=30,
            kde=True,
            multiple="stack",
            palette="coolwarm",
            ax=axes[0]
        )
        axes[0].set_title(f"{hname} by Iodine Quartile")
        axes[0].set_xlabel(hname)
        axes[0].set_ylabel("Frequency")

        # Bar Plot (Mean ± SD)
        sns.barplot(
            data=df,
            x="Iodine_Group",
            y=hvar,
            estimator=np.mean,
            ci="sd",
            palette="coolwarm",
            errorbar="sd",
            capsize=0.2,
            ax=axes[1]
        )
        axes[1].set_title(f"{hname} by Iodine Quartile (Mean ± SD)")
        axes[1].set_xlabel("Iodine Quartile")
        axes[1].set_ylabel(hname)

        plt.tight_layout()
        plt.show()

        # Run statistical tests
        run_stats(df, hvar, "Iodine_Group")

# --------------------------------
# Run Analysis
# --------------------------------
analyze_iodine_vs_thyroid(df_clean)
# Out:
# /tmp/ipython-input-7-1864510425.py:95: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-7-1864510425.py:95: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# 📊 LBXT4F Analysis by Iodine_Group:
#
# Frequency Table:
# Iodine_Group
# Q1 (Low)     583
# Q2           583
# Q3           583
# Q4 (High)    583
# Name: count, dtype: int64
#
# Descriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):
#                 N      Mean  Median       Std   Q1    Q3   IQR
# Iodine_Group
# Q1 (Low)      583  0.817136     0.8  0.235158  0.7  0.90  0.20
# Q2            583  0.797650     0.8  0.141813  0.7  0.90  0.20
# Q3            583  0.800120     0.8  0.163045  0.7  0.90  0.20
# Q4 (High)     583  0.779520     0.8  0.156651  0.7  0.89  0.19
#
# ...

# %% [markdown]
# # Analysis of results (Iodine)

# %% [markdown]
# Free T4
# Role: Regulates metabolism, heart rate, and body temperature.
#
# Key Results:
# - Highest mean in Q1 (Low iodine): 0.817
# - Lowest mean in Q4 (High iodine): 0.780
# - Kruskal-Wallis Test p = 0.0325 → Significant difference
#
# Interpretation:
# - Free T4 levels significantly differ across iodine groups.
# - Lower iodine levels are associated with slightly higher Free T4, while higher iodine may be linked to reduced Free T4.
# - Could suggest a compensatory response in low iodine conditions.
#
# Total T3
# Role: Active thyroid hormone involved in metabolic regulation.
#
# Key Results:
# - Highest mean in Q1 (Low iodine): 120.6
# - Lowest mean in Q4 (High iodine): 115.9
# - Kruskal-Wallis Test p = 0.0104 → Significant difference
#
# Interpretation:
# - Total T3 levels also significantly differ with iodine intake.
# - A slight decrease in Total T3 with increasing iodine levels.
# - May indicate iodine excess suppressing T3 production in high-intake groups.
#
# TSH
# Role: Stimulates the thyroid gland to produce T3 and T4.
#
# Key Results:
# - Lowest mean in Q2 (Moderate iodine): 1.814
# - Highest mean in Q4 (High iodine): 2.307
# - Kruskal-Wallis Test p = 0.05939 → No Significant difference
#
# Interpretation:
# - TSH levels are not affected by iodine intake.
# - Despite slight numerical differences in means, these differences are not strong enough to be statistically meaningful based on the Kruskal–Wallis test (p = 0.5939).
# - Though in theory TSH levels would change due to high or low iodine intake, but further testing will be required in order to come to a more accurate conclusion as our sample space is too small (2408 participants)
#
# Note on Distributions:
# - All groups for all hormones failed the normality test (p < 0.05).
# - Many groups show extreme skewness and kurtosis, meaning results may be influenced by outliers or non-normal spread.
#
# Overall Conclusion:
# - Free T4 and Total T3 significantly affected by iodine intake.
# - Low iodine is linked to higher Free T4 and T3.
# - The results suggest that both iodine deficiency and excess can disrupt thyroid hormone balance, reinforcing the need for optimal iodine levels.

# %% [markdown]
# Age

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis, shapiro, mannwhitneyu, kruskal
import pandas as pd
import numpy as np

# ----------------------------------
# Helper Function: Statistical Summary + Mann–Whitney U + Kruskal–Wallis
# ----------------------------------
def run_stats(df, hormone, group_col):
    print(f"\n📊 {hormone} Analysis by {group_col}:")

    # Frequency table
    print("\nFrequency Table:")
    print(df[group_col].value_counts().sort_index())

    # Descriptive stats
    grouped = df.groupby(group_col)[hormone]
    stats_table = grouped.agg([
        'count', 'mean', 'median', 'std',
        lambda x: x.quantile(0.25),
        lambda x: x.quantile(0.75)
    ])
    stats_table.columns = ['N', 'Mean', 'Median', 'Std', 'Q1', 'Q3']
    stats_table['IQR'] = stats_table['Q3'] - stats_table['Q1']
    print("\nDescriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):")
    print(stats_table)

    # Normality, skew, kurtosis
    print("\nNormality Tests and Distribution Metrics:")
    for group, values in grouped:
        values = values.dropna()
        if len(values) < 3:
            print(f"{group}: Not enough data (N={len(values)})")
            continue
        s, p = shapiro(values) if len(values) <= 5000 else (np.nan, np.nan)
        print(f"\nGroup: {group}")
        print(f"  N = {len(values)}")
        print(f"  Skewness: {skew(values):.4f}")
        print(f"  Kurtosis: {kurtosis(values):.4f}")
        if not np.isnan(s):
            print(f"  Shapiro-Wilk: W = {s:.4f}, p = {p:.4f} →", "Not normal" if p < 0.05 else "Normal")
        else:
            print("  Shapiro-Wilk skipped (N > 5000)")

    # Non-parametric test
    valid_groups = [group.dropna() for _, group in grouped if len(group.dropna()) >= 3]
    if len(valid_groups) < 2:
        print("\n→ Not enough valid groups for statistical testing")
    elif len(valid_groups) == 2:
        u_stat, p_u = mannwhitneyu(*valid_groups, alternative='two-sided')
        print(f"\nMann–Whitney U Test: U = {u_stat:.4f}, p = {p_u:.4f}")
        print("→ Significant difference" if p_u < 0.05 else "→ No significant difference")
    else:
        h_stat, p_kw = kruskal(*valid_groups)
        print(f"\nKruskal–Wallis Test: H = {h_stat:.4f}, p = {p_kw:.4f}")
        print("→ Significant difference (non-parametric)" if p_kw < 0.05 else "→ No significant difference (non-parametric)")

# ----------------------------------
# Main Function for Plotting by Age Group
# ----------------------------------
def analyze_age_vs_thyroid(df):
    df = df.copy()

    # Bin age into 10-year intervals
    age_bins = [18, 30, 40, 50, 60, 70, 80, 99]
    age_labels = ["18–29", "30–39", "40–49", "50–59", "60–69", "70–79", "80+"]
    df["Age_Group"] = pd.cut(df["RIDAGEYR"], bins=age_bins, labels=age_labels, right=False)

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        # Histogram
        sns.histplot(
            data=df,
            x=hvar,
            hue="Age_Group",
            multiple="stack",
            bins=30,
            palette="coolwarm",
            kde=True,
            ax=axes[0]
        )
        axes[0].set_title(f"{hname} by Age Group")
        axes[0].set_xlabel(hname)
        axes[0].set_ylabel("Frequency")

        # Barplot (Mean ± SD)
        sns.barplot(
            data=df,
            x="Age_Group",
            y=hvar,
            estimator=np.mean,
            ci="sd",
            palette="coolwarm",
            errorbar="sd",
            capsize=0.2,
            ax=axes[1]
        )
        axes[1].set_title(f"{hname} by Age Group (Mean ± SD)")
        axes[1].set_xlabel("Age Group")
        axes[1].set_ylabel(hname)

        plt.tight_layout()
        plt.show()

        run_stats(df, hvar, "Age_Group")

# ----------------------------------
# Run Age-Based Analysis
# ----------------------------------
analyze_age_vs_thyroid(df_clean)
# Out:
# /tmp/ipython-input-8-4262473177.py:95: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-8-4262473177.py:95: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# 📊 LBXT4F Analysis by Age_Group:
#
# Frequency Table:
# Age_Group
# 18–29    481
# 30–39    449
# 40–49    421
# 50–59    407
# 60–69    428
# 70–79    168
# 80+       54
# Name: count, dtype: int64
#
# Descriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):
#              N      Mean  Median       Std   Q1    Q3   IQR
# Age_Group
# 18–29      481  0.810644     0.8  0.162567  0.7  0.90  0.20
# 30–39      449  0.792272     0.8  0.232782  0.7  0.84  0.14
# 40–49      421  0.778076     0.8  0.152077  0.7  0.85  0.15
# 50–59      407  0.780786     0.8  0.142737  0.7  0.89  0.19
# ...

# %% [markdown]
# # Analysis of results (Age)

# %% [markdown]
# Free T4
# What it does: Controls metabolism, energy, and body temperature.
# Kruskal-Wallis Test p = 0.0000 → ✅ Significant difference
#
# Trend:
# - Lowest mean in middle-aged group (40–49): 0.778
# - Highest mean in 80+ group: 0.892
#
# Interpretation:
# - Free T4 levels tend to increase again in older adults (70–80+) after dipping in middle age.
# - May suggest age-related changes in thyroid function, possibly due to decreased peripheral conversion or increased thyroid output.
#
# Total T3
# What it does: Regulates metabolism, more biologically active than T4.
# Kruskal-Wallis Test p = 0.0000 → ✅ Significant difference
#
# Trend:
# - T3 levels consistently decline with age
# - Highest mean in young adults (18–29): 125.9
# - Lowest mean in 80+: 101.2
#
# Interpretation:
# - Total T3 levels decline progressively with age, possibly due to:
# - Reduced T4-to-T3 conversion
# - Decreased metabolic demand
# - May reflect a normal aging process in thyroid function.
#
# TSH
# What it does: Stimulates thyroid hormone production (T3 and T4).
# Kruskal-Wallis Test p = 0.0000 → ✅ Significant difference
#
# Trend:
# - TSH levels increase with age
# - Lowest mean in 18–29: 1.68
# - Highest mean in 80+: 2.95
#
# Interpretation:
# - TSH rises with age possibly due to:
# - Reduced thyroid sensitivity
# - Compensatory increase to maintain T3/T4 levels
# - Suggests a trend toward subclinical hypothyroidism in older adults
#
# Normality:
# - All age groups failed normality tests (except T3 in 80+), with high skewness and kurtosis, suggesting:
# - Non-normal distributions
# - Outliers or heavy tails may affect averages
#
# Final Conclusion:
# - Age significantly affects thyroid hormone levels.
# - Free T4: Dips in middle age, then rises in elderly
# - Total T3: Steadily declines with age
# - TSH: Gradually increases with age
# - These changes suggest age-related shifts in thyroid physiology, possibly affecting metabolism and endocrine function in older adults.

# %% [markdown]
# BMI

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis, shapiro, mannwhitneyu, kruskal
import pandas as pd
import numpy as np

# ----------------------------------
# Helper Function: Summary + Normality + Mann–Whitney/Kruskal
# ----------------------------------
def run_stats(df, hormone, group_col):
    print(f"\n📊 {hormone} Analysis by {group_col}:")

    # Frequency table
    print("\nFrequency Table:")
    print(df[group_col].value_counts().sort_index())

    # Descriptive stats
    grouped = df.groupby(group_col)[hormone]
    stats_table = grouped.agg([
        'count', 'mean', 'median', 'std',
        lambda x: x.quantile(0.25),
        lambda x: x.quantile(0.75)
    ])
    stats_table.columns = ['N', 'Mean', 'Median', 'Std', 'Q1', 'Q3']
    stats_table['IQR'] = stats_table['Q3'] - stats_table['Q1']
    print("\nDescriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):")
    print(stats_table)

    # Normality, skewness, kurtosis
    print("\nNormality Tests and Distribution Metrics:")
    for group, values in grouped:
        values = values.dropna()
        if len(values) < 3:
            print(f"{group}: Not enough data (N={len(values)})")
            continue
        s, p = shapiro(values) if len(values) <= 5000 else (np.nan, np.nan)
        print(f"\nGroup: {group}")
        print(f"  N = {len(values)}")
        print(f"  Skewness: {skew(values):.4f}")
        print(f"  Kurtosis: {kurtosis(values):.4f}")
        if not np.isnan(s):
            print(f"  Shapiro-Wilk: W = {s:.4f}, p = {p:.4f} →", "Not normal" if p < 0.05 else "Normal")
        else:
            print("  Shapiro-Wilk skipped (N > 5000)")

    # Statistical testing
    valid_groups = [g.dropna() for _, g in grouped if len(g.dropna()) >= 3]
    if len(valid_groups) < 2:
        print("\n→ Not enough valid groups for statistical testing")
    elif len(valid_groups) == 2:
        u_stat, p_u = mannwhitneyu(*valid_groups, alternative='two-sided')
        print(f"\nMann–Whitney U Test: U = {u_stat:.4f}, p = {p_u:.4f}")
        print("→ Significant difference" if p_u < 0.05 else "→ No significant difference")
    else:
        h_stat, p_kw = kruskal(*valid_groups)
        print(f"\nKruskal–Wallis Test: H = {h_stat:.4f}, p = {p_kw:.4f}")
        print("→ Significant difference (non-parametric)" if p_kw < 0.05 else "→ No significant difference (non-parametric)")

# ----------------------------------
# Main Function for Plotting by BMI Groups
# ----------------------------------
def analyze_bmi_vs_thyroid(df):
    df = df.copy()

    # Define BMI groups
    bmi_bins = [12.5, 18.5, 24.9, 29.9, 40, 100]
    bmi_labels = ["Underweight", "Normal", "Overweight", "Obese", "Extreme Obesity"]
    df["BMI_Group"] = pd.cut(df["BMXBMI"], bins=bmi_bins, labels=bmi_labels, right=False)

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        # Histogram
        sns.histplot(
            data=df,
            x=hvar,
            hue="BMI_Group",
            multiple="stack",
            bins=30,
            palette="viridis",
            kde=True,
            ax=axes[0]
        )
        axes[0].set_title(f"{hname} by BMI Category")
        axes[0].set_xlabel(hname)
        axes[0].set_ylabel("Frequency")

        # Barplot (Mean ± SD)
        sns.barplot(
            data=df,
            x="BMI_Group",
            y=hvar,
            estimator=np.mean,
            ci="sd",
            palette="viridis",
            errorbar="sd",
            capsize=0.2,
            ax=axes[1]
        )
        axes[1].set_title(f"{hname} by BMI Category (Mean ± SD)")
        axes[1].set_xlabel("BMI Group")
        axes[1].set_ylabel(hname)

        plt.tight_layout()
        plt.show()

        run_stats(df, hvar, "BMI_Group")

# ----------------------------------
# Run BMI-Based Analysis
# ----------------------------------
analyze_bmi_vs_thyroid(df_clean)
# Out:
# /tmp/ipython-input-9-4046410288.py:95: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-9-4046410288.py:95: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# 📊 LBXT4F Analysis by BMI_Group:
#
# Frequency Table:
# BMI_Group
# Underweight         13
# Normal             509
# Overweight         911
# Obese              821
# Extreme Obesity    124
# Name: count, dtype: int64
#
# Descriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):
#                    N      Mean  Median       Std    Q1      Q3     IQR
# BMI_Group
# Underweight       13  0.829231     0.8  0.162453  0.76  0.9000  0.1400
# Normal           509  0.818566     0.8  0.230120  0.70  0.9000  0.2000
# Overweight       911  0.794435     0.8  0.158922  0.70  0.9000  0.2000
# ...

# %% [markdown]
# # Analysis of results (BMI)

# %% [markdown]
# Overall Summary
# Only TSH shows a statistically significant difference across BMI groups (p = 0.0087).
#
# Free T4 and Total T3 do not significantly differ (p > 0.05).
#
# Most groups fail normality tests, so results should be interpreted with caution.
#
# Free T4
# Function: Regulates metabolism and energy.
#
# Kruskal-Wallis Test p = 0.1042 → ❌ No significant difference
#
# Trend:
#
# Slightly higher mean in underweight (0.829) and normal (0.818) groups.
#
# Slight decline in obese (0.796) and extreme obesity (0.787).
#
# Interpretation:
#
# Free T4 levels are relatively stable across BMI, with only minor variation.
#
# Total T3
# Function: Active form of thyroid hormone controlling metabolic rate.
#
# Kruskal-Wallis Test p = 0.3515 → ❌ No significant difference
#
# Trend:
#
# T3 levels slightly increase with BMI.
#
# From 114.2 (underweight) → 119.8 (extreme obesity)
#
# Interpretation:
#
# T3 production may be slightly upregulated in obesity, but the differences are not statistically significant.
#
# TSH
# Function: Stimulates thyroid hormone production.
#
# Kruskal-Wallis Test p = 0.0000 → ✅ Significant difference
#
# Trend:
#
# TSH increases across BMI categories:
#
# Underweight: 1.48
#
# Normal: 1.94
#
# Overweight: 2.03
#
# Extreme obesity: 2.90
#
# Interpretation:
#
# Higher TSH in obesity may reflect compensatory thyroid stimulation to maintain T3/T4 levels.
#
# Could indicate a trend toward subclinical hypothyroidism or thyroid resistance in individuals with higher BMI.
#
# Conclusion:
# TSH is significantly affected by BMI → Higher BMI is associated with higher TSH levels.
#
# Free T4 and Total T3 are not significantly different, but may slightly vary with body fat.
#
# Suggests that thyroid regulation may be more stressed in obese individuals, even if hormone levels remain stable.

# %% [markdown]
# Smoking frequency

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis, shapiro, mannwhitneyu, kruskal
import pandas as pd
import numpy as np

# ----------------------------------
# Helper Function for Statistical Summary
# ----------------------------------
def run_stats(df, hormone, group_col):
    print(f"\n📊 {hormone} Analysis by {group_col}:")

    # Frequency table
    print("\nFrequency Table:")
    print(df[group_col].value_counts().sort_index())

    # Descriptive stats
    grouped = df.groupby(group_col)[hormone]
    stats_table = grouped.agg([
        'count', 'mean', 'median', 'std',
        lambda x: x.quantile(0.25),
        lambda x: x.quantile(0.75)
    ])
    stats_table.columns = ['N', 'Mean', 'Median', 'Std', 'Q1', 'Q3']
    stats_table['IQR'] = stats_table['Q3'] - stats_table['Q1']
    print("\nDescriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):")
    print(stats_table)

    # Normality, skew, kurtosis per group
    print("\nNormality Tests and Distribution Metrics:")
    for group, values in grouped:
        values = values.dropna()
        if len(values) < 3:
            print(f"{group}: Not enough data (N={len(values)})")
            continue
        s, p = shapiro(values) if len(values) <= 5000 else (np.nan, np.nan)
        print(f"\nGroup: {group}")
        print(f"  N = {len(values)}")
        print(f"  Skewness: {skew(values):.4f}")
        print(f"  Kurtosis: {kurtosis(values):.4f}")
        if not np.isnan(s):
            print(f"  Shapiro-Wilk: W = {s:.4f}, p = {p:.4f} →", "Not normal" if p < 0.05 else "Normal")
        else:
            print("  Shapiro-Wilk skipped (N > 5000)")

    # Statistical test
    valid_groups = [group.dropna() for _, group in grouped if len(group.dropna()) >= 3]
    if len(valid_groups) < 2:
        print("\n→ Not enough valid groups for statistical testing")
    elif len(valid_groups) == 2:
        u_stat, p_u = mannwhitneyu(*valid_groups, alternative='two-sided')
        print(f"\nMann–Whitney U Test: U = {u_stat:.4f}, p = {p_u:.4f}")
        print("→ Significant difference" if p_u < 0.05 else "→ No significant difference")
    else:
        h_stat, p_kw = kruskal(*valid_groups)
        print(f"\nKruskal–Wallis Test: H = {h_stat:.4f}, p = {p_kw:.4f}")
        print("→ Significant difference (non-parametric)" if p_kw < 0.05 else "→ No significant difference (non-parametric)")

# ----------------------------------
# Main Function for Plotting by Smoking Frequency
# ----------------------------------
def analyze_smoking_vs_thyroid(df):
    df = df.copy()

    # Recode Smoking Frequency
    smoking_labels = {1: "Every day", 2: "Some days", 3: "Not at all"}
    df["Smoking_Frequency"] = df["SMQ040"].map(smoking_labels)

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        # Histogram
        sns.histplot(
            data=df, x=hvar, hue="Smoking_Frequency", multiple="stack",
            bins=30, kde=True, palette="viridis", ax=axes[0]
        )
        axes[0].set_title(f"{hname} by Smoking Frequency")
        axes[0].set_xlabel(hname)
        axes[0].set_ylabel("Frequency")

        # Barplot (Mean ± SD)
        sns.barplot(
            data=df, x="Smoking_Frequency", y=hvar,
            estimator=np.mean, ci="sd", errorbar="sd", palette="viridis",
            capsize=0.2, ax=axes[1]
        )
        axes[1].set_title(f"{hname} by Smoking Frequency (Mean ± SD)")
        axes[1].set_xlabel("Smoking Frequency")
        axes[1].set_ylabel(hname)

        plt.tight_layout()
        plt.show()

        run_stats(df, hvar, "Smoking_Frequency")

# ----------------------------------
# Run Smoking-Based Analysis
# ----------------------------------
analyze_smoking_vs_thyroid(df_clean)
# Out:
# /tmp/ipython-input-10-1810557939.py:88: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-10-1810557939.py:88: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# 📊 LBXT4F Analysis by Smoking_Frequency:
#
# Frequency Table:
# Smoking_Frequency
# Every day     290
# Not at all    507
# Some days     125
# Name: count, dtype: int64
#
# Descriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):
#                      N      Mean  Median       Std   Q1   Q3  IQR
# Smoking_Frequency
# Every day          290  0.798345     0.8  0.182829  0.7  0.9  0.2
# Not at all         507  0.818797     0.8  0.242342  0.7  0.9  0.2
# Some days          125  0.808480     0.8  0.199593  0.7  0.9  0.2
#
# Normality Tests and Distribution Metrics:
#
# Group: Every day
# ...

# %% [markdown]
# # Analysis of results (Smoking Frequency)

# %% [markdown]
# Overall Summary
# Total T3 (p = 0.0003) and TSH (p = 0.0001) show statistically significant differences between smoking groups.
#
# Free T4 (p = 0.2174) shows no significant difference.
#
# All groups fail normality tests → Results should be interpreted cautiously.
#
# Free T4
# Function: Helps regulate energy and metabolism.
#
# Kruskal-Wallis Test p = 0.2174 → ❌ No significant difference
#
# Trend:
#
# Mean values are very similar across all groups (~0.80).
#
# Interpretation:
#
# Smoking frequency does not appear to influence Free T4 levels in a meaningful way.
#
# Total T3
# Function: The biologically active thyroid hormone.
#
# Kruskal-Wallis Test p = 0.0003 → ✅ Significant difference
#
# Trend:
#
# Highest mean T3 in "Some days" smokers (124.0)
#
# Lower in "Every day" smokers (119.1)
#
# Lowest in non-smokers (116.0)
#
# Interpretation:
#
# Occasional smokers show elevated T3, possibly due to stimulatory effects of nicotine on thyroid activity.
#
# Could reflect acute vs. chronic exposure effects.
#
# TSH
# Function: Stimulates production of T3 and T4 from the thyroid.
#
# Kruskal-Wallis Test p = 0.0001 → ✅ Significant difference
#
# Trend:
#
# Lowest TSH in "Some days" (1.65) and "Every day" smokers (1.68)
#
# Highest in non-smokers (2.12)
#
# Interpretation:
#
# Smokers tend to have lower TSH, possibly due to:
#
# Nicotine stimulating thyroid hormone release.
#
# A negative feedback loop reducing TSH secretion.
#
# Supports existing findings that smoking may suppress TSH levels.
#
# Conclusion:
# Smoking frequency influences thyroid function:
#
# T3 is elevated in occasional smokers.
#
# TSH is suppressed in daily and occasional smokers.
#
# Free T4 remains stable across all groups.
#
# Suggests nicotine exposure may modulate thyroid activity, especially TSH suppression and T3 increase.

# %% [markdown]
# Sleep

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis, shapiro, mannwhitneyu, kruskal
import numpy as np

# -------------------------------
# Statistical Summary Function
# -------------------------------
def run_stats(df, hormone, group_col):
    print(f"\n📊 {hormone} Analysis by {group_col}:")

    # Frequency table
    print("\nFrequency Table:")
    print(df[group_col].value_counts(dropna=False).sort_index())

    # Descriptive stats
    grouped = df.groupby(group_col)[hormone]
    stats_table = grouped.agg([
        'count', 'mean', 'median', 'std',
        lambda x: x.quantile(0.25),
        lambda x: x.quantile(0.75)
    ])
    stats_table.columns = ["N", "Mean", "Median", "Std", "Q1", "Q3"]
    stats_table["IQR"] = stats_table["Q3"] - stats_table["Q1"]
    print("\nDescriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):")
    print(stats_table)

    # Normality tests
    print("\nNormality Tests and Distribution Metrics:")
    for group, values in grouped:
        values = values.dropna()
        if len(values) < 3:
            print(f"{group}: Not enough data (N={len(values)})")
            continue
        s, p = shapiro(values) if len(values) <= 5000 else (np.nan, np.nan)
        print(f"\nGroup: {group}")
        print(f"  N = {len(values)}")
        print(f"  Skewness: {skew(values):.4f}")
        print(f"  Kurtosis: {kurtosis(values):.4f}")
        if not np.isnan(s):
            print(f"  Shapiro-Wilk: W={s:.4f}, p = {p:.4f} →", "Not normal" if p < 0.05 else "Normal")
        else:
            print("  Shapiro-Wilk skipped (N > 5000)")

    # Statistical testing
    valid_groups = [g.dropna() for _, g in grouped if len(g.dropna()) >= 3]
    if len(valid_groups) < 2:
        print("\n→ Not enough valid groups for statistical testing")
    elif len(valid_groups) == 2:
        u_stat, p_u = mannwhitneyu(*valid_groups, alternative='two-sided')
        print(f"\nMann–Whitney U Test: U = {u_stat:.4f}, p = {p_u:.4f}")
        print("→ Significant difference" if p_u < 0.05 else "→ No significant difference")
    else:
        h_stat, p_kw = kruskal(*valid_groups)
        print(f"\nKruskal–Wallis Test: H = {h_stat:.4f}, p = {p_kw:.4f}")
        print("→ Significant difference (non-parametric)" if p_kw < 0.05 else "→ No significant difference (non-parametric)")

# -------------------------------
# Plot & Analyze by Sleep Hours
# -------------------------------
def analyze_sleep_vs_thyroid(df):
    df = df.copy()
    df = df.dropna(subset=["SLD010H"])
    df["Sleep_Hours"] = df["SLD010H"].astype(int)

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        fig, axes = plt.subplots(1, 2, figsize=(14, 6))

        # Histogram
        sns.histplot(
            data=df, x=hvar, hue="Sleep_Hours", bins=30, kde=True,
            multiple="stack", palette="Spectral", ax=axes[0]
        )
        axes[0].set_title(f"{hname} by Sleep Duration")
        axes[0].set_xlabel(hname)
        axes[0].set_ylabel("Frequency")

        # Barplot (Mean ± SD)
        sns.barplot(
            data=df, x="Sleep_Hours", y=hvar,
            estimator=np.mean, ci="sd", errorbar="sd",
            palette="Spectral", capsize=0.2, ax=axes[1]
        )
        axes[1].set_title(f"{hname} by Sleep Duration (Mean ± SD)")
        axes[1].set_xlabel("Sleep Hours")
        axes[1].set_ylabel(hname)

        plt.tight_layout()
        plt.show()

        run_stats(df, hvar, "Sleep_Hours")

# -------------------------------
# Run Sleep Analysis
# -------------------------------
analyze_sleep_vs_thyroid(df_clean)
# Out:
# /tmp/ipython-input-11-3717203545.py:85: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(
# /tmp/ipython-input-11-3717203545.py:85: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# 📊 LBXT4F Analysis by Sleep_Hours:
#
# Frequency Table:
# Sleep_Hours
# 1       4
# 2       3
# 3      26
# 4      93
# 5     231
# 6     552
# 7     648
# 8     679
# 9     106
# 10     32
# 11     10
# 12     20
# Name: count, dtype: int64
#
# Descriptive Statistics (Mean, Median, Std, Q1, Q3, IQR):
#                N      Mean  Median       Std     Q1     Q3    IQR
# Sleep_Hours
# 1              4  0.975000    0.75  0.485627  0.700  1.025  0.325
# 2              3  0.733333    0.70  0.057735  0.700  0.750  0.050
# 3             26  0.808462    0.82  0.135785  0.700  0.900  0.200
# ...

# %% [markdown]
# # Analysis of results (Sleep Duration)

# %% [markdown]
# Overall Summary
# TSH (p = 0.0073) shows a statistically significant difference between sleep hour groups.
#
# Free T4 (p = 0.5115) and Total T3 (p = 0.4933) show no significant differences.
#
# Most groups fail normality tests → Interpret results with caution due to outliers and skewed distributions.
#
# Free T4
# Function: Helps regulate energy and metabolism.
#
# Kruskal-Wallis Test p = 0.5115 → ❌ No significant difference
#
# Trend:
#
# - Mean values range from 0.73 to 0.98, but mostly stable around 0.78–0.81 across 3–10 hours of sleep.
#
# - IQR consistently ~0.2
#
# Interpretation:
# - Free T4 levels are not influenced by sleep duration in a meaningful way. Slight differences may be due to random variation.
#
# Total T3
#
# Function: The biologically active thyroid hormone.
#
# Kruskal-Wallis Test p = 0.4933 → ❌ No significant difference
#
# Trend:
#
# - Mean levels are relatively stable from 114–120 across common sleep durations (4–10h).
#
# - Slight elevation in 1-hour sleepers (133) and drop in 11-hour sleepers (98.5), but both groups have very small sample sizes.
#
# Interpretation:
# - Sleep hours do not significantly affect Total T3 levels. Outliers in small groups (e.g. 1h, 11h) may distort the extremes.
#
# TSH
# Function: Stimulates production of T3 and T4 from the thyroid.
#
# Kruskal-Wallis Test p = 0.0073 → ✅ Significant difference
#
# Trend:
#
# - TSH levels peak sharply at 11 hours of sleep (mean = 9.3, SD = 14.9), likely driven by outliers.
#
# - Other groups (4–10h) show stable TSH values around 1.6–2.2
#
# Interpretation:
# - The significant difference is mainly due to an extreme spike at 11 hours. This is likely not representative of typical population effects and could reflect health issues or data anomalies in a small group.
#
# Conclusion:
# - Free T4 and Total T3 are not affected by sleep duration in this population.
#
# - TSH levels show a significant difference, but only due to an outlier-prone group (11h sleepers).

# %% [markdown]
# # Further Graphs

# %% [markdown]
# The following graphs are used in order to more accurately analyse the trends as some of the predictors cannot be accurately described using a histogram

# %% [markdown]
# Iodine
#
#
# ---
#
#
# Iodine concentration is primarily a continuous variable. However for the histogram to work we had to bin it.
# As such a histogram cannot accurately present each individual value.
# So we would use a scatter plot or line plot in order to better visualise the data and intepret it

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_iodine_vs_thyroid(df):
    df = df.copy()
    df = df.dropna(subset=["URXUIO"])

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x="URXUIO", y=hvar, alpha=0.4, edgecolor=None, label="Data Points")
        sns.lineplot(data=df, x="URXUIO", y=hvar, color="red", label="Trend", errorbar=None)

        plt.title(f"{hname} vs Urinary Iodine (μg/L)")
        plt.xlabel("Urinary Iodine (μg/L)")
        plt.ylabel(hname)
        plt.xlim(0, 1000)  # <-- Added x-axis limit
        plt.legend()
        plt.tight_layout()
        plt.show()

plot_iodine_vs_thyroid(df_clean)

# %% [markdown]
# Age though it does have categories, it has too many variables, thus by using a line plot it becomes easier to visualise the trend

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# -------------------------------
# Scatter + Line Plot for Age
# -------------------------------
def plot_age_vs_thyroid(df):
    df = df.copy()
    df = df.dropna(subset=["RIDAGEYR"])  # Ensure age is not missing

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        plt.figure(figsize=(10, 6))
        sns.scatterplot(data=df, x="RIDAGEYR", y=hvar, alpha=0.4, label="Data Points")
        sns.lineplot(data=df, x="RIDAGEYR", y=hvar, color="red", label="Trend", errorbar=None)
        plt.title(f"{hname} vs Age")
        plt.xlabel("Age (years)")
        plt.ylabel(hname)
        plt.legend()
        plt.tight_layout()
        plt.show()

# --------------------------------
# Run the Plotting Function
# --------------------------------
plot_age_vs_thyroid(df_clean)

# %% [markdown]
# **Smoking**
#
# ---
# Smoking frequency is a categorical variable. To effectively visualise how thyroid hormone concentrations vary across smoking categories, a box plot was used. Box plots are appropriate for comparing distributions of a continuous outcome variable across discrete groups, as they display the median, interquartile range (IQR), and any potential outliers. This allows for clear comparison of central tendencies and variability between smoking groups, making it easier to interpret differences in hormone levels associated with smoking status.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def boxplot_smoking_vs_thyroid(df):
    df = df.copy()

    # Recode Smoking Frequency
    smoking_labels = {1: "Every day", 2: "Some days", 3: "Not at all"}
    df["Smoking_Frequency"] = df["SMQ040"].map(smoking_labels)

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        plt.figure(figsize=(8, 6))
        sns.boxplot(
            data=df,
            x="Smoking_Frequency",
            y=hvar,
            hue="Smoking_Frequency",  # Explicitly set hue
            palette="Set2",
            legend=False # Hide the legend as hue is the same as x
        )
        plt.title(f"{hname} by Smoking Frequency")
        plt.xlabel("Smoking Frequency")
        plt.ylabel(hname)
        plt.tight_layout()
        plt.show()
# --------------------------------
# Run the Plotting Function
# --------------------------------
boxplot_smoking_vs_thyroid(df_clean)

# %% [markdown]
# **Gender**
#
# ---
#
# Gender is a categorical variable. To effectively visualize how thyroid hormone concentrations differ between gender groups, a box plot was used. Box plots are ideal for comparing the distributions of a continuous variable across discrete categories, as they show the median, interquartile range (IQR), and any potential outliers. This enables clear comparison of central tendencies and variability between genders, helping to interpret differences in hormone levels associated with gender.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_gender_vs_thyroid_boxplots(df):
    df = df.copy()
    df = df.dropna(subset=["Gender"])  # Ensure Gender data is present

    hormones = {
        "LBXT4F": "Free T4 (ng/dL)",
        "LBXTT3": "Total T3 (ng/dL)",
        "LBXTSH1": "TSH (uIU/mL)"
    }

    for hvar, hname in hormones.items():
        plt.figure(figsize=(8, 6))
        sns.boxplot(data=df, x="Gender", y=hvar, palette="Set2")
        plt.title(f"{hname} by Gender - Box Plot")
        plt.xlabel("Gender")
        plt.ylabel(hname)
        plt.tight_layout()
        plt.show()

# Run the plotting function
plot_gender_vs_thyroid_boxplots(df_clean)
# Out:
# /tmp/ipython-input-12-460742377.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Gender", y=hvar, palette="Set2")
# /tmp/ipython-input-12-460742377.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Gender", y=hvar, palette="Set2")
# /tmp/ipython-input-12-460742377.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Gender", y=hvar, palette="Set2")

# %% [markdown]
# # Annual Trend
#
#
# ---
#
# This section presents annual trends in median concentrations of TSH, Free T4, and Total T3 across the NHANES 2007–2012 cycles. By visualizing median values and the percentage of participants in clinically abnormal ranges, we aim to identify potential shifts in thyroid hormone distributions over time. These trends can provide insight into temporal patterns in thyroid function and inform public health monitoring efforts.

# %% [markdown]
# # New Section

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- Simulated NHANES-like data (replace with your own data as needed) ---
np.random.seed(0)
n = 300
df_raw = pd.DataFrame({
    'SDDSRVYR': np.random.choice([5,6,7], n),
    'LBXTSH1': np.random.normal(loc=2.5, scale=1.0, size=n),
    'LBXT4F': np.random.normal(loc=1.2, scale=0.3, size=n),
    'LBXTT3': np.random.normal(loc=110, scale=20, size=n)
})

# --- Data cleaning ---
df_clean = df_raw[
    (df_raw['LBXTSH1'] > 0) &
    (df_raw['LBXT4F'] > 0) &
    (df_raw['LBXTT3'] > 0)
].copy()

# Map cycles to readable labels
cycle_map = {5: "2007-2008", 6: "2009-2010", 7: "2011-2012"}
df_clean['Cycle'] = df_clean['SDDSRVYR'].map(cycle_map)

# Create indicator columns BEFORE grouping
df_clean['High_TSH'] = df_clean['LBXTSH1'] > 4.5
df_clean['Low_TSH'] = df_clean['LBXTSH1'] < 0.4

# Compute median hormone levels by cycle
medians = df_clean.groupby('Cycle')[['LBXTSH1', 'LBXT4F', 'LBXTT3']].median().reset_index()

# --- Plot median TSH ---
plt.figure(figsize=(6,4))
plt.plot(medians['Cycle'], medians['LBXTSH1'], marker='o', color='blue')
plt.title("Median TSH by Cycle")
plt.xlabel("NHANES Cycle")
plt.ylabel("Median TSH (uIU/mL)")
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# --- Plot median Free T4 ---
plt.figure(figsize=(6,4))
plt.plot(medians['Cycle'], medians['LBXT4F'], marker='o', color='green')
plt.title("Median Free T4 by Cycle")
plt.xlabel("NHANES Cycle")
plt.ylabel("Median Free T4 (ng/dL)")
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# --- Plot median Total T3 ---
plt.figure(figsize=(6,4))
plt.plot(medians['Cycle'], medians['LBXTT3'], marker='o', color='purple')
plt.title("Median Total T3 by Cycle")
plt.xlabel("NHANES Cycle")
plt.ylabel("Median Total T3 (ng/dL)")
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# --- Calculate % Elevated TSH ---
elevated_counts = df_clean.groupby('Cycle')['High_TSH'].sum()
total_counts = df_clean.groupby('Cycle')['High_TSH'].count()
elevated_pct = (elevated_counts / total_counts * 100).reset_index()
elevated_pct.columns = ['Cycle', 'Elevated_TSH_Pct']

# --- Bar plot of Elevated TSH ---
plt.figure(figsize=(6,5))
plt.bar(elevated_pct['Cycle'], elevated_pct['Elevated_TSH_Pct'], color='salmon')
plt.title("Percentage of Participants with TSH > 4.5 uIU/mL")
plt.xlabel("NHANES Cycle")
plt.ylabel("% Elevated TSH")
plt.ylim(0, max(elevated_pct['Elevated_TSH_Pct'].max() + 2, 5))
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# --- Calculate % Low TSH ---
low_counts = df_clean.groupby('Cycle')['Low_TSH'].sum()
low_pct = (low_counts / total_counts * 100).reset_index()
low_pct.columns = ['Cycle', 'Low_TSH_Pct']  # <-- FIXED NAME

# --- Bar plot of Low TSH ---
plt.figure(figsize=(6,5))
plt.bar(low_pct['Cycle'], low_pct['Low_TSH_Pct'], color='skyblue')  # <-- FIXED NAME
plt.title("Percentage of Participants with TSH < 0.4 uIU/mL")
plt.xlabel("NHANES Cycle")
plt.ylabel("% Low TSH")
plt.ylim(0, max(low_pct['Low_TSH_Pct'].max() + 2, 5))
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Median TSH by cycle:
#
#
# ---
# Initial observation:
#
# From 2007-2008 the median TSH was ~2.52, moving on to 2009-2010 the median went up to ~2.70, finally from 2011-2012 the median went down to ~2.42.
#
# Analysis:
# - There's a peak in TSH levels during 2009–2010, followed by a sharp decline in 2011–2012.
#
# - This pattern suggests a non-linear trend in population-level TSH over the years.
#
# - Possible reasons could include methodological changes, population differences, or external factors like environmental exposure, medication, or dietary iodine intake.
#
# - The median of TSH remained relatively similar

# %% [markdown]
# Median Free T4 by cycle:
#
#
# ---
# Initial observation:
#
# From 2007-2008 the median Free T4 was ~1.2150, moving on to 2009-2010 the median went up to ~1.2175, finally from 2011-2012 the median went up further to ~1.2350.
#
# Analysis:
# - Steady upward trend in Free T4 levels across the three NHANES cycles.
#
# - While the increase is small (~0.02 ng/dL), it's consistent.
#
# - Could be attributed to:
#
#   - Improved lab techniques
#
#   - Environmental or dietary changes
#
#   - Shifts in population characteristics

# %% [markdown]
# Median Total T3 by cycle:
#
# Initial observation:
#
# From 2007-2008 the median Total T3 was ~107.5, moving on to 2009-2010 the median went up to ~110.0, finally from 2011-2012 the median went down to ~108.5
#
# Analysis:
# - Slight fluctuation observed across the 3 cycles:
#
# - A modest increase from 2007–2008 to 2009–2010 (+2.5 ng/dL).
#
# - Followed by a small dip in 2011–2012 (–1.5 ng/dL).
#
# - Overall, Total T3 levels remained relatively stable across years.
#
# - Variations may reflect:
#
#   - Demographic changes in NHANES samples.
#
#   - Seasonal or environmental influences.
#
#   - Measurement variability, not necessarily physiological changes.

# %% [markdown]
# Percentage of participants with TSH > 4.5 uIU/mL by cycle:
#
# Initial observation:
#
# From 2007-2008 the percentage of participants with elevated TSH was ~4%, moving on to 2009-2010 the percentage went down to ~1%, finally from 2011-2012 the median went up to ~3%.
#
# Analysis:
# - Notable dip in elevated TSH cases from 2007–2008 to 2009–2010 (from ~4% to ~1%).
#
# - A partial rebound occurred in 2011–2012 (~3%).
#
# - These fluctuations may indicate:
#
#   - Improved early detection or thyroid treatment during the 2009–2010 cycle.
#
#   - Sampling variability or demographic shifts across cycles.
#
#   - Potential influence of environmental or lifestyle factors (e.g., iodine intake, smoking trends).

# %% [markdown]
# Percentage of participants with TSH < 0.4 uIU/mL by cycle:
#
# Initial observation:
#
# From 2007-2008 the percentage of participants with elevated TSH was ~3%, moving on to 2009-2010 the percentage went down to ~2%, finally from 2011-2012 the median went down further to ~0%.
#
# Analysis:
# - Steady decline in low TSH prevalence across the three cycles.
#
# - This trend may suggest:
#
#   - Improved thyroid regulation in the population over time.
#
#   - Reduced cases of hyperthyroidism or subclinical hyperthyroid states.
#
#   - Changes in diagnostic thresholds, screening, or treatment practices.
#
# - The near-zero prevalence in 2011–2012 could reflect:
#
#   - Successful medical interventions for hyperthyroid individuals.
#
#   - Possible sampling bias or increased exclusion of overt cases.

# %% [markdown]
# **Thyroid Medication**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

years = ["2007", "2009", "2011"]
cycles = ["E", "F", "G"]

modules = {
    "demographics": {
        "prefix": "DEMO",
        "vars": ["SEQN", "RIDAGEYR", "RIDRETH1"]
    },
    "medications": {
        "prefix": "RXQ_RX",
        "vars": ["SEQN", "RXDDRUG"]
    }
}

thyroid_keywords = ["thyroid", "levothyroxine", "liothyronine", "armour"]

def load_cycle_data(year, cycle):
    # Load demographics data
    demo_url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/DEMO_{cycle}.XPT"
    demo = pd.read_sas(demo_url)[modules["demographics"]["vars"]]
    # Filter for Hispanic adults (18+)
    demo = demo[(demo["RIDAGEYR"] >= 18) & (demo["RIDRETH1"].isin([1, 2]))]

    # Load medications data
    meds_url = f"https://wwwn.cdc.gov/Nchs/Data/Nhanes/Public/{year}/DataFiles/RXQ_RX_{cycle}.XPT"
    meds = pd.read_sas(meds_url)[modules["medications"]["vars"]]

    # Decode RXDDRUG if bytes
    if meds["RXDDRUG"].dtype == "O" and isinstance(meds["RXDDRUG"].iloc[0], bytes):
        meds["RXDDRUG"] = meds["RXDDRUG"].apply(lambda x: x.decode('utf-8') if isinstance(x, bytes) else x)

    # Filter thyroid medications by keywords (case-insensitive)
    meds_thyroid = meds[meds["RXDDRUG"].str.lower().str.contains('|'.join(thyroid_keywords), na=False)]

    # Get SEQN for participants on thyroid meds
    thyroid_seqns = set(meds_thyroid["SEQN"])

    # Add flag for thyroid medication use
    demo["Thyroid_Med_Use"] = demo["SEQN"].apply(lambda x: 1 if x in thyroid_seqns else 0)

    return demo

# Collect prevalence per cycle
results = []
for y, c in zip(years, cycles):
    df_cycle = load_cycle_data(y, c)
    prevalence = df_cycle["Thyroid_Med_Use"].mean() * 100  # percent
    results.append({"Cycle": f"{y}-{int(y)+1}", "Thyroid_Med_Use_%": prevalence})

df_results = pd.DataFrame(results)

# Plot thyroid medication use prevalence
plt.figure(figsize=(8,5))
plt.bar(df_results["Cycle"], df_results["Thyroid_Med_Use_%"], color='teal')
plt.ylim(0, df_results["Thyroid_Med_Use_%"].max() + 1)
plt.ylabel("Thyroid Medication Use (%)")
plt.title("Thyroid Medication Use Prevalence in Hispanic Adults (NHANES 2007-2012)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# There is a slight decreasing trend in thyroid medication use among Hispanic adults over the 6-year period.
# From 2007–2008 to 2011–2012, the prevalence appears to drop by approximately 0.4 percentage points.
#
# **Interpretation**
#
# - This decline, though modest, may reflect:
# - Changes in diagnosis rates
# - Access to care
# - Population health trends
# - Differences in survey sampling or medication adherence

# %% [markdown]
# # Citations

# %% [markdown]
# Hollowell, J.G., Staehling, N.W., Flanders, W.D., Hannon, W.H., Gunter, E.W., Spencer, C.A. & Braverman, L.E., 2002. Serum TSH, T(4), and thyroid antibodies in the United States population (1988 to 1994): National Health and Nutrition Examination Survey (NHANES III). The Journal of Clinical Endocrinology & Metabolism, 87(2), pp.489-499. https://doi.org/10.1210/jcem.87.2.8182
#
#
# Alevizaki, M., Saltiki, K., Voidonikola, P., Mantzou, E., Papamichael, C. & Stamatelopoulos, K., 2005. Free thyroxine rather than TSH correlates with lipid parameters in euthyroid individuals: the importance of thyroid hormone reference ranges. European Journal of Endocrinology, 152(5), pp.747-753. https://doi.org/10.1530/eje.1.01912
#
#
# National Cancer Institute, n.d. Thyroid gland. [online] NCI Dictionary of Cancer Terms. Available at: https://www.cancer.gov/publications/dictionaries/cancer-terms/def/thyroid-gland
